# %% [markdown]
# # Day 3 Agenda
#
# - Dict methods
# - tuples, sets?
# - Looping, if-else
# - File I/O
# - File Formats

# %%
item_prices = {'biscuit': 10.25, 'chocolate': 100.25, 'candy': 0.99}

# %%
item_prices.keys()
# Out:
# dict_keys(['biscuit', 'chocolate', 'candy'])

# %%
item_prices.values()
# Out:
# dict_values([10.25, 100.25, 0.99])

# %%
item_prices.items()
# Out:
# dict_items([('biscuit', 10.25), ('chocolate', 100.25), ('candy', 0.99)])

# %%
t = (1,2,3)

# %%
type(t)
# Out:
# tuple

# %%
t[0]
t[-1]
t[1:]
# Out:
# (2, 3)

# %%
for loopvar in iterable:
    ...
    ...
    ...

...

# %%
x = 10

# %%
for num in [1,2,3,4]:
    print(num)
    print(num**2)
# Out:
# 1
# 1
# 2
# 4
# 3
# 9
# 4
# 16

# %%
for key in item_prices.keys():
    print(key)
# Out:
# biscuit
# chocolate
# candy

# %%
item_prices.items()
# Out:
# dict_items([('biscuit', 10.25), ('chocolate', 100.25), ('candy', 0.99)])

# %%
for item in item_prices.items():
    print(item[0], item[1])
# Out:
# biscuit 10.25
# chocolate 100.25
# candy 0.99

# %%
t
# Out:
# (1, 2, 3)

# %%
x = 10
y = 20
x, y = 10, 20    # parallel/tuple assignment
x, y = [10, 20]

# %%
for key, value in item_prices.items():
    print(key, value)
# Out:
# biscuit 10.25
# chocolate 100.25
# candy 0.99

# %%
for value in item_prices.values():
    value *= 1.05

# %%
choc_price = item_prices['chocolate']
choc_price *= 1.05    # increase val by 5%

# %%
for key in item_prices.keys():
    item_prices[key] *= 1.05

# %%
item_prices
# Out:
# {'biscuit': 10.762500000000001, 'chocolate': 105.2625, 'candy': 1.0395}

# %%
item_prices.get('coffee', 'not found')
# Out:
# 'not found'

# %%
item_prices.get('candy')
# Out:
# 1.0395

# %%
item_counts.get('coffee', 0)

# %%
item_prices.update({'coffee': 225.50, 'brandy': 999.99, 'candy': 1.25})

# %%
item_prices
# Out:
# {'biscuit': 10.762500000000001,
#  'chocolate': 105.2625,
#  'candy': 1.25,
#  'coffee': 225.5,
#  'brandy': 999.99}

# %%
added_items = {'coffee': 225.50, 'brandy': 999.99, 'candy': 1.25}

# %%
item_prices.update(added_items)

# %%
item_prices.update(**added_items)

# %%
# Dict of squares of nums 1-10

squares = {}

# %%
for num in range(1,11):
    squares[num] = num**2

# %%
squares
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81, 10: 100}

# %%
sentence = 'the quick brown fox jumps over the lazy dog'

# %%
# word_lengths = {'the': 3, 'quick': 5, ... }
word_lengths = {}

# %%
for word in sentence.split():
    word_lengths[word] = len(word)

word_lengths
# Out:
# {'the': 3,
#  'quick': 5,
#  'brown': 5,
#  'fox': 3,
#  'jumps': 5,
#  'over': 4,
#  'lazy': 4,
#  'dog': 3}

# %%
len(word_lengths)
# Out:
# 8

# %%
len(sentence.split())
# Out:
# 9

# %%
len_words = {3: 'dog', 5: 'quick',}
len_words = {
    3: ['the', 'fox', 'the', 'dog'],
    5: ['quick', 'brown', 'jumps'], 
}

# %% [markdown]
# # https://github.com/py-train/npci

# %%
f = open(r'/Users/ashishgulati/Train/npci/npci/data/alice.txt', encoding='utf-8')
f
# Out:
# <_io.TextIOWrapper name='/Users/ashishgulati/Train/npci/npci/data/alice.txt' mode='r' encoding='utf-8'>

# %%
f.readable()
# Out:
# True

# %%
f.readline()
# Out:
# 'whatsoever. You may copy it, give it away or re-use it under the terms\n'

# %%
'a' -> 97
'A' -> 65

# %%
f.readlines()
# Out:
# ['of the Project Gutenberg License included with this ebook or online\n',
#  'at www.gutenberg.org. If you are not located in the United States,\n',
#  'you will have to check the laws of the country where you are located\n',
#  'before using this eBook.\n',
#  '\n',
#  "Title: Alice's Adventures in Wonderland\n",
#  '\n',
#  'Author: Lewis Carroll\n',
#  '\n',
#  'Release date: June 27, 2008 [eBook #11]\n',
#  '                Most recently updated: November 10, 2024\n',
#  '\n',
#  'Language: English\n',
#  '\n',
#  'Credits: Arthur DiBianca and David Widger\n',
#  '\n',
#  '\n',
#  "*** START OF THE PROJECT GUTENBERG EBOOK ALICE'S ADVENTURES IN WONDERLAND ***\n",
#  '[Illustration]\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  'Alice’s Adventures in Wonderland\n',
#  '\n',
#  'by Lewis Carroll\n',
#  '\n',
#  'THE MILLENNIUM FULCRUM EDITION 3.0\n',
#  '\n',
#  'Contents\n',
#  '\n',
#  ' CHAPTER I.     Down the Rabbit-Hole\n',
#  ' CHAPTER II.    The Pool of Tears\n',
# ...

# %%
f.readline()
# Out:
# ''

# %%
f.tell()
# Out:
# 174357

# %%
f.seek(0)
# Out:
# 0

# %%
f.readline()
# Out:
# "\ufeffThe Project Gutenberg eBook of Alice's Adventures in Wonderland\n"

# %%
f.read(100)
# Out:
# '    \nThis ebook is for the use of anyone anywhere in the United States and\nmost other parts of the w'

# %%
f.read()
# Out:
# "orld at no cost and with almost no restrictions\nwhatsoever. You may copy it, give it away or re-use it under the terms\nof the Project Gutenberg License included with this ebook or online\nat www.gutenberg.org. If you are not located in the United States,\nyou will have to check the laws of the country where you are located\nbefore using this eBook.\n\nTitle: Alice's Adventures in Wonderland\n\nAuthor: Lewis Carroll\n\nRelease date: June 27, 2008 [eBook #11]\n                Most recently updated: November 10, 2024\n\nLanguage: English\n\nCredits: Arthur DiBianca and David Widger\n\n\n*** START OF THE PROJECT GUTENBERG EBOOK ALICE'S ADVENTURES IN WONDERLAND ***\n[Illustration]\n\n\n\n\nAlice’s Adventures in Wonderland\n\nby Lewis Carroll\n\nTHE MILLENNIUM FULCRUM EDITION 3.0\n\nContents\n\n CHAPTER I.     Down the Rabbit-Hole\n CHAPTER II.    The Pool of Tears\n CHAPTER III.   A Caucus-Race and a Long Tale\n CHAPTER IV.    The Rabbit Sends in a Little Bill\n CHAPTER V.     Advice f
# ...

# %%
while line != '':
    ...

# %%
f.seek(0)
# Out:
# 0

# %%
f.seek(0)
for line in f:
    # print(line, end='')
    print(line.strip())
# Out:
# ﻿The Project Gutenberg eBook of Alice's Adventures in Wonderland
#
# This ebook is for the use of anyone anywhere in the United States and
# most other parts of the world at no cost and with almost no restrictions
# whatsoever. You may copy it, give it away or re-use it under the terms
# of the Project Gutenberg License included with this ebook or online
# at www.gutenberg.org. If you are not located in the United States,
# you will have to check the laws of the country where you are located
# before using this eBook.
#
# Title: Alice's Adventures in Wonderland
#
# Author: Lewis Carroll
#
# Release date: June 27, 2008 [eBook #11]
# Most recently updated: November 10, 2024
#
# Language: English
#
# Credits: Arthur DiBianca and David Widger
#
#
# *** START OF THE PROJECT GUTENBERG EBOOK ALICE'S ADVENTURES IN WONDERLAND ***
# [Illustration]
#
#
#
#
# Alice’s Adventures in Wonderland
#
# by Lewis Carroll
#
# THE MILLENNIUM FULCRUM EDITION 3.0
#
# Contents
#
# ...

# %%
nwords = 0
f.seek(0)
for line in f:
    nwords += len(line.split())

nwords
# Out:
# 29564

# %%
line = "Title: Alice's Adventures in Wonderland"

# %%
words = line.split()
words
# Out:
# ['Title:', "Alice's", 'Adventures', 'in', 'Wonderland']

# %%
len(words)
# Out:
# 5

# %%
len(line.split())
# Out:
# 5

# %%
nwords = 0
for word in words:
    nwords += 1

# %%
nwords
# Out:
# 5

# %%
# How many times is 'Alice' present in this text
character = 'QUEEN'

alice_count = 0
f.seek(0)
for line in f:
    alice_count += line.upper().count(character)

alice_count
# Out:
# 77

# %%
def count_character(character):
    '''Count number of occurences of character in Alice text
    '''
    count = 0
    f.seek(0)
    
    for line in f:
        count += line.upper().count(character.upper())
        
    return count

# %%
count_character('Alice')
# Out:
# 403

# %%
count_character(

# %%
line = 'alice hello Alice how are you ALICE!!'

# %%
line.upper().count('ALICE')
# Out:
# 3

# %%
chars = ['alice', 'queen', 'hatter', 'king', 'rabbit']

# %%
for char in chars:
    print(char, count_character(char))
# Out:
# alice 403
# queen 77
# hatter 57
# king 179
# rabbit 54

# %%
char_count = {}
for char in chars:
    char_count[char] = count_character(char)

# %%
char_count
# Out:
# {'alice': 403, 'queen': 77, 'hatter': 57, 'king': 179, 'rabbit': 54}
