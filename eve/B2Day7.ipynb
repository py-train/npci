# %% [markdown]
# ## HTTP Clients & POST requests

# %%
import requests

# %%
r = requests.get('https://google.com')
r
# Out:
# <Response [200]>

# %%
r.status_code
# Out:
# 200

# %%
r.headers
# Out:
# {'Date': 'Wed, 29 Jan 2025 10:08:31 GMT', 'Expires': '-1', 'Cache-Control': 'private, max-age=0', 'Content-Type': 'text/html; charset=ISO-8859-1', 'Content-Security-Policy-Report-Only': "object-src 'none';base-uri 'self';script-src 'nonce-fvEME_ouWCL-ThYEwWi47g' 'strict-dynamic' 'report-sample' 'unsafe-eval' 'unsafe-inline' https: http:;report-uri https://csp.withgoogle.com/csp/gws/other-hp", 'Accept-CH': 'Sec-CH-Prefers-Color-Scheme', 'P3P': 'CP="This is not a P3P policy! See g.co/p3phelp for more info."', 'Content-Encoding': 'gzip', 'Server': 'gws', 'X-XSS-Protection': '0', 'X-Frame-Options': 'SAMEORIGIN', 'Set-Cookie': 'AEC=AZ6Zc-VxuwIAHNyw2KiHGe2ohVBIc4bvN1irTlf_3N-U0j81dUgWfr5Z4w; expires=Mon, 28-Jul-2025 10:08:31 GMT; path=/; domain=.google.com; Secure; HttpOnly; SameSite=lax, NID=521=HKHaaYhnKt04o4OFrqTKKD_x197JU8WuEhcsYFbDkf5wc6BXyNUeMcxkQ1-TsT32KUnOVbiX6D7kv98-YdrDc2u17eR5OHEUsSGSSm8WDKZ7ZyU53thBNbJKDeiQXPTXYtmJXRKD1EjHEJ9HFYwmhEKzonVNCT0hyotZ2zG4lue012Kzf1VYuLBDqSzhu7wqMduZ
# ...

# %%
r.headers['Content-Type']
# Out:
# 'text/html; charset=ISO-8859-1'

# %%
baseuri = 'https://jsonplaceholder.typicode.com/todos'

# %%
r = requests.get(baseuri)
r
# Out:
# <Response [200]>

# %%
r.headers['Content-Type']
# Out:
# 'application/json; charset=utf-8'

# %%
r.content
# Out:
# b'[\n  {\n    "userId": 1,\n    "id": 1,\n    "title": "delectus aut autem",\n    "completed": false\n  },\n  {\n    "userId": 1,\n    "id": 2,\n    "title": "quis ut nam facilis et officia qui",\n    "completed": false\n  },\n  {\n    "userId": 1,\n    "id": 3,\n    "title": "fugiat veniam minus",\n    "completed": false\n  },\n  {\n    "userId": 1,\n    "id": 4,\n    "title": "et porro tempora",\n    "completed": true\n  },\n  {\n    "userId": 1,\n    "id": 5,\n    "title": "laboriosam mollitia et enim quasi adipisci quia provident illum",\n    "completed": false\n  },\n  {\n    "userId": 1,\n    "id": 6,\n    "title": "qui ullam ratione quibusdam voluptatem quia omnis",\n    "completed": false\n  },\n  {\n    "userId": 1,\n    "id": 7,\n    "title": "illo expedita consequatur quia in",\n    "completed": false\n  },\n  {\n    "userId": 1,\n    "id": 8,\n    "title": "quo adipisci enim quam ut ab",\n    "completed": true\n  },\n  {\n    "userId": 1,\n    "id": 9,\n    "title": "mole
# ...

# %%
import json

# %%
json.loads(r.content)
# Out:
# [{'userId': 1, 'id': 1, 'title': 'delectus aut autem', 'completed': False},
#  {'userId': 1,
#   'id': 2,
#   'title': 'quis ut nam facilis et officia qui',
#   'completed': False},
#  {'userId': 1, 'id': 3, 'title': 'fugiat veniam minus', 'completed': False},
#  {'userId': 1, 'id': 4, 'title': 'et porro tempora', 'completed': True},
#  {'userId': 1,
#   'id': 5,
#   'title': 'laboriosam mollitia et enim quasi adipisci quia provident illum',
#   'completed': False},
#  {'userId': 1,
#   'id': 6,
#   'title': 'qui ullam ratione quibusdam voluptatem quia omnis',
#   'completed': False},
#  {'userId': 1,
#   'id': 7,
#   'title': 'illo expedita consequatur quia in',
#   'completed': False},
#  {'userId': 1,
#   'id': 8,
#   'title': 'quo adipisci enim quam ut ab',
#   'completed': True},
#  {'userId': 1,
#   'id': 9,
#   'title': 'molestiae perspiciatis ipsa',
#   'completed': False},
#  {'userId': 1,
#   'id': 10,
#   'title': 'illo est ratione doloremque quia maiores aut',
# ...

# %%
r.json()
# Out:
# [{'userId': 1, 'id': 1, 'title': 'delectus aut autem', 'completed': False},
#  {'userId': 1,
#   'id': 2,
#   'title': 'quis ut nam facilis et officia qui',
#   'completed': False},
#  {'userId': 1, 'id': 3, 'title': 'fugiat veniam minus', 'completed': False},
#  {'userId': 1, 'id': 4, 'title': 'et porro tempora', 'completed': True},
#  {'userId': 1,
#   'id': 5,
#   'title': 'laboriosam mollitia et enim quasi adipisci quia provident illum',
#   'completed': False},
#  {'userId': 1,
#   'id': 6,
#   'title': 'qui ullam ratione quibusdam voluptatem quia omnis',
#   'completed': False},
#  {'userId': 1,
#   'id': 7,
#   'title': 'illo expedita consequatur quia in',
#   'completed': False},
#  {'userId': 1,
#   'id': 8,
#   'title': 'quo adipisci enim quam ut ab',
#   'completed': True},
#  {'userId': 1,
#   'id': 9,
#   'title': 'molestiae perspiciatis ipsa',
#   'completed': False},
#  {'userId': 1,
#   'id': 10,
#   'title': 'illo est ratione doloremque quia maiores aut',
# ...

# %%
r = requests.get(baseuri + '/1')
r.json()
# Out:
# {'userId': 1, 'id': 1, 'title': 'delectus aut autem', 'completed': False}

# %% [markdown]
# ### POST request

# %%
data = {'userId': 10, 'id': 1, 'title': 'Testing! Testing!', 'completed': False}

# %%
r = requests.post(baseuri, data=data)
r
# Out:
# <Response [201]>

# %%
r.json()
# Out:
# {'userId': '10', 'id': 201, 'title': 'Testing! Testing!', 'completed': 'False'}

# %% [markdown]
# ### Testing POST request

# %%
baseuri = 'http://127.0.0.1:8000/empsearch/'

# %%
r = requests.post(baseuri, data={'na': 'abc', 'id': 123})
r
# Out:
# <Response [200]>

# %%
r.headers['Content-Type']
# Out:
# 'text/html; charset=utf-8'

# %%
r.content
# Out:
# b'<html>\n    <body>\n        <h1>Failure</h1>\n        <p>The operation Failed! Try later.</p>\n    </body>\n</html>'

# %%
emp = {'name': 'abc', 'id': 123}

# %%
'name' in emp
# Out:
# True

# %%
'NAME' in emp
# Out:
# False
